# %%
import picamera
from IPython.display import Image
camera = picamera.PiCamera()
camera = picamera.PiCamera()
camera.rotation = 180

# %%
camera.capture("image.jpg")
Image(filename ='image.jpg')

# %%
import time
import datetime

i=0
while(1):
    
    camera.capture("images/negative/neg_" + str(datetime.datetime.now().strftime("%Y%m%d_%H%M%S")) + ".jpg")
    time.sleep(1)
    i=i+1
    print(i)
